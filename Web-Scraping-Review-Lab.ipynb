# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a webpage
# * Scrape all image URLs from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a webpage

# %% [markdown]
# Download the contents of the webpage

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/thought-leadership/institute-business-value/en-us/report/intelligent-it-automation?lnk=hpls1us
# https://www.ibm.com/think/insights/ai-in-devops?lnk=hpls2us
# https://www.ibm.com/products/instana/assets/devops-fullstack-observability?lnk=hprc1us
# https://www.ibm.com/new/announcements/bring-production-grade-tests-to-pre-prod-instana-adds-synthetic-monitoring-to-your-ci-cd?lnk=hprc2us
# https://www.ibm.com/think/insights/lets-create-smarter-business?lnk=hprc3us
# https://developer.ibm.com/get-started/generative-ai/?lnk=hprc4us
# https://www.ibm.com/case-studies/sixt?lnk=hpcs1us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs2us
# https://www.ibm.com/case-studies/us-open?lnk=hpcs3us
# https://www.ibm.com/case-studies/avid-solutions-international?lnk=hpcs4us
# https://www.ibm.com/case-studies/ufc?lnk=hpcs5us
# https://www.ibm.com/products/offers-and-discounts?lnk=hpdo1us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/solutions/ai-agents?lnk=hpfp2us
# https://www.ibm.com/solutions/data-and-ai?lnk=hpfp3us
# https://www.ibm.com/solutions/automation?lnk=hpfp4us
# https://www.ibm.com/solutions/hybrid-cloud?lnk=hpfp5us
# https://www.ibm.com/solutions/ai-models?lnk=hpfp6us
# https://www.ibm.com/solutions/analytics?lnk=hpfp7us
# https://www.ibm.com/solutions/security?lnk=hpfp8us
# https://www.ibm.com/consulting?lnk=hpfp9us
# https://www.ibm.com/about?lnk=hpii1us
# https://www.ibm.com/history?lnk=hpii1us
# https://research.ibm.com?lnk=hpii1us
# https://www.ibm.com/quantum?lnk=hpii1us
# https://www.ibm.com/careers?lnk=hpii1us
# https://skillsbuild.org?lnk=hpii1us
# https://newsroom.ibm.com/2025-11-19-atruvia-and-ibm-sign-long-term-agreement-to-future-proof-it-platforms-for-autonomous-and-sustainable-banking
# https://newsroom.ibm.com/ufc-and-ibm-introduce-ai-driven-in-fight-insights
# https://newsroom.ibm.com/ibm-x-web-summit-sports-tech-startup-challenge
# https://newsroom.ibm.com/2025-11-13-ibm-study-chief-data-officers-redefine-strategies-as-ai-ambitions-outpace-readiness
# https://newsroom.ibm.com/2025-11-12-ibm-delivers-new-quantum-processors,-software,-and-algorithm-breakthroughs-on-path-to-advantage-and-fault-tolerance
# https://newsroom.ibm.com/2025-11-11-unipol-assicurazioni-leverages-ibm-watsonx-to-build-a-new-ai-driven-automation-platform

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/dco-native-prospecting-2b?ts=1763348702329&dpr=off
# https://assets.ibm.com/is/image/ibm/watsonxdata_technicalillustration_crop?ts=1763348710204&dpr=off
# https://assets.ibm.com/is/image/ibm/ai_productivity4_light_hiu?ts=1763348713663&dpr=off
# https://assets.ibm.com/is/image/ibm/foundational-models-g10?ts=1763348725125&dpr=off
# https://assets.ibm.com/is/image/ibm/sixt-smarter-business-case-study-regular-medium-ls?ts=1763348725837&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_ferrari_video_thumb_01?ts=1763348726385&dpr=off
# https://assets.ibm.com/is/image/ibm/us-open-crowd-court?ts=1763348727077&dpr=off
# https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1763348727611&dpr=off
# https://assets.ibm.com/is/image/ibm/1731592760476?ts=1763348728262&dpr=off
# https://assets.ibm.com/is/content/ibm/big-blue-for-you-promotional-banner-gif2?ts=1763348728920&dpr=off
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1763348734696&dpr=off

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below URL contains a html table with data about colors and color codes.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a website, you need to examine the contents, and the way data is organized on the website. Open the above URL in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(URL).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %% [markdown]
# # Get all rows from the table

# %%
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# <!--
# ## Change Log
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-10-29  | 0.2  | Madhusudhan Moole |  Updated lab |
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
